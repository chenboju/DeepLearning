# %% [markdown]
# <a href="https://colab.research.google.com/github/chenboju/DeepLearning/blob/main/2_DPKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras深度學習初體驗1
# 利用keras套件，產生一個32個神經元的深度學習模型進行訓練

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=784))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import numpy as np
data = np.random.random((1000, 784))
#隨機產生1000筆資料，每筆資料包含十個float數字
labels = np.random.randint(10, size=(1000, 10))
#隨機產生1000筆資料，每筆資料上限為2(意思就是0 或 1)
print(data[0])
print(labels[0])
# Out:
# [2.27555998e-01 9.07804657e-01 7.12185714e-01 1.74265046e-01
#  7.81585710e-01 2.07315925e-01 2.95514017e-01 6.96812850e-01
#  4.40846933e-02 9.33742372e-01 8.18568708e-01 4.97078141e-01
#  2.21006772e-01 4.72888435e-01 9.19729181e-01 1.92214919e-01
#  3.23710827e-01 6.00191382e-01 8.07816970e-01 4.57082797e-02
#  5.27414141e-01 7.04905508e-01 5.36808478e-02 3.37439745e-01
#  6.21407212e-01 4.20411706e-01 8.26301608e-01 9.97858645e-02
#  4.39426488e-01 5.13333096e-01 4.11233197e-02 4.90410409e-01
#  6.81658233e-01 9.31494643e-01 8.12709297e-01 4.54514925e-01
#  9.02239824e-01 9.01461143e-01 6.84121574e-01 7.39279328e-02
#  3.90562905e-01 8.60508881e-01 9.77968963e-01 1.65760159e-01
#  1.75349642e-01 2.48560642e-01 7.92213393e-01 9.58921804e-01
#  6.05216745e-01 4.15932324e-01 4.85392340e-01 8.67610932e-01
#  9.57998673e-01 5.35648407e-01 9.96572622e-02 3.16102732e-01
#  6.64112545e-01 2.98302050e-01 6.09191252e-01 4.02311318e-01
# ...

# %%
model.fit(data, labels, epochs=10) #epochs 訓練次數
score=model.evaluate(data, labels)
print(score[1])
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 3ms/step - loss: 11596.3066 - accuracy: 0.0840
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 12587.9326 - accuracy: 0.0840
# Epoch 3/10
# 32/32 [==============================] - 0s 4ms/step - loss: 13672.1846 - accuracy: 0.0840
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 14653.3623 - accuracy: 0.0840
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 15713.4004 - accuracy: 0.0840
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 16727.0977 - accuracy: 0.0840
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 17717.8828 - accuracy: 0.0840
# Epoch 8/10
# 32/32 [==============================] - 0s 4ms/step - loss: 18742.2246 - accuracy: 0.0840
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 19776.3223 - accuracy: 0.0840
# Epoch 10/10
# ...

# %%
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 11088.8203 - accuracy: 0.0840
# 0.08399999886751175
